# %%
import pandas as pd
import matplotlib as plt

# %%
happy_df = pd.read_csv("happiness_df.csv")

def get_happiness_scores(country_name):
    mask = happy_df['Country'] == country_name
    happiness_scores = happy_df.loc[mask, 'Happiness Score'].tolist()
    return happiness_scores

def plot_country(happiness_scores):
    years = range(2015, 2023)
    plt.plot(years, happiness_scores)
    plt.xlabel('Year')
    plt.ylabel('Happiness Scores')
    plt.title('Change in Happiness from 2015 to 2022')
    plt.show()

# Get a list of unique countries in the original data frame
countries = happy_df['Country'].unique()

# Create a new data frame with columns for each year
new_df = pd.DataFrame(columns=['Country', "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022"])

for country in countries:
    country_values = [country]
    for year in range(2015, 2023):
        value = happy_df[(happy_df['Country'] == country) & (happy_df['Year'] == year)]['Happiness Score']
        if len(value) > 0:
            country_values.append(value.values[0])
        else:
            country_values.append(None)
    new_df.loc[len(new_df)] = country_values
# Out:
#          Country   2015   2016   2017   2018   2019    2020   2021   2022
# 0        Finland  7.587  7.526  7.537  7.632  7.769  7.8087  7.842  7.821
# 1        Denmark  7.561  7.509  7.522  7.594  7.600  7.6456  7.620  7.636
# 2        Iceland  7.527  7.501  7.504  7.555  7.554  7.5599  7.571  7.557
# 3    Switzerland  7.522  7.498  7.494  7.495  7.494  7.5045  7.554  7.512
# 4    Netherlands  7.427  7.413  7.469  7.487  7.488  7.4880  7.464  7.415
# ..           ...    ...    ...    ...    ...    ...     ...    ...    ...
# 142      Rwanda*  3.896  3.832  3.657  3.774  3.933  3.6528  3.615  3.268
# 143     Zimbabwe  3.845  3.763  3.644  3.692  3.802  3.5733  3.600  2.995
# 144      Lebanon  3.819  3.739  3.603  3.632  3.775  3.5380  3.512  2.955
# 145  Afghanistan  3.781  3.739  3.593  3.590  3.663  3.5274  3.467  2.404
# 146          NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
#
# [147 rows x 9 columns]

# %%
work_life = pd.read_csv("work-life.csv")

work_life = work_life[work_life["ISC11A"] == "T"]
work_life = work_life[work_life["MEASURE"] == "VALUE"]
family_resp = work_life[work_life["INDICATOR"] == "EQLS_PERC_NEG_FAMILY"]
work_conc = work_life[work_life["INDICATOR"] == "EQLS_PERC_NEG_JOB"]
work_life
# Out:
#       COUNTRY           Country ISC11A             ISCED-A 2011 SEX Gender  \
# 6         AUS         Australia      T  All levels of education   T  Total
# 14        AUS         Australia      T  All levels of education   T  Total
# 22        AUT           Austria      T  All levels of education   T  Total
# 30        AUT           Austria      T  All levels of education   T  Total
# 38        BEL           Belgium      T  All levels of education   T  Total
# ...       ...               ...    ...                      ...  ..    ...
# 1406      LTU         Lithuania      T  All levels of education   T  Total
# 1414      SVN          Slovenia      T  All levels of education   T  Total
# 1422  BEL-VLG          Flanders      T  All levels of education   T  Total
# 1430  GBR-ENG           England      T  All levels of education   T  Total
# 1438  GBR-NIR  Northern Ireland      T  All levels of education   T  Total
#
#          AGE          Age PIAAC_CATEGORY Category                   INDICATOR  \
# 6     Y25T64  25-64 years              T    Total           EQLS_PERC_NEG_JOB
# 14    Y25T64  25-64 years              T    Total        EQLS_PERC_NEG_FAMILY
# 22    Y25T64  25-64 years              T    Total           EQLS_PERC_NEG_JOB
# 30    Y25T64  25-64 years              T    Total        EQLS_PERC_NEG_FAMILY
# 38    Y25T64  25-64 years              T    Total           EQLS_PERC_NEG_JOB
# ...      ...          ...            ...      ...                         ...
# 1406  Y45T64  45-64 years              T    Total  PIAAC_PERC_BOOKS_ONCE_WEEK
# 1414  Y45T64  45-64 years              T    Total  PIAAC_PERC_BOOKS_ONCE_WEEK
# 1422  Y45T64  45-64 years              T    Total  PIAAC_PERC_BOOKS_ONCE_WEEK
# 1430  Y45T64  45-64 years              T    Total  PIAAC_PERC_BOOKS_ONCE_WEEK
# 1438  Y45T64  45-64 years              T    Total  PIAAC_PERC_BOOKS_ONCE_WEEK
#
#                                               Indicator MEASURE Measure  YEAR  \
# 6     Percentage of adults who reported that over th...   VALUE   Value  2015
# 14    Percentage of adults who reported that over th...   VALUE   Value  2015
# 22    Percentage of adults who reported that over th...   VALUE   Value  2016
# 30    Percentage of adults who reported that over th...   VALUE   Value  2016
# 38    Percentage of adults who reported that over th...   VALUE   Value  2016
# ...                                                 ...     ...     ...   ...
# 1406  "Percentage of adults who read books at least ...   VALUE   Value  2015
# 1414  "Percentage of adults who read books at least ...   VALUE   Value  2015
# 1422  "Percentage of adults who read books at least ...   VALUE   Value  2012
# 1430  "Percentage of adults who read books at least ...   VALUE   Value  2012
# 1438  "Percentage of adults who read books at least ...   VALUE   Value  2012
#
#       Reference year  Value Flag Codes Flags
# 6               2015   63.0        NaN   NaN
# 14              2015   35.0        NaN   NaN
# 22              2016   43.0        NaN   NaN
# 30              2016   22.0        NaN   NaN
# 38              2016   50.0        NaN   NaN
# ...              ...    ...        ...   ...
# 1406            2015   31.0        NaN   NaN
# 1414            2015   23.0        NaN   NaN
# 1422            2012   30.0        NaN   NaN
# 1430            2012   57.0        NaN   NaN
# 1438            2012   46.0        NaN   NaN
#
# [180 rows x 19 columns]

# %%
family_resp = family_resp.sort_values("Value")
family_resp
# Out:
#     COUNTRY         Country ISC11A             ISCED-A 2011 SEX Gender  \
# 222     NLD     Netherlands      T  All levels of education   T  Total
# 30      AUT         Austria      T  All levels of education   T  Total
# 318     SWE          Sweden      T  All levels of education   T  Total
# 206     LUX      Luxembourg      T  All levels of education   T  Total
# 78      DNK         Denmark      T  All levels of education   T  Total
# 254     NOR          Norway      T  All levels of education   T  Total
# 94      FIN         Finland      T  All levels of education   T  Total
# 110     FRA          France      T  All levels of education   T  Total
# 46      BEL         Belgium      T  All levels of education   T  Total
# 398     EST         Estonia      T  All levels of education   T  Total
# 174     IRL         Ireland      T  All levels of education   T  Total
# 382     CHL           Chile      T  All levels of education   T  Total
# 126     DEU         Germany      T  All levels of education   T  Total
# 350     GBR  United Kingdom      T  All levels of education   T  Total
# 302     ESP           Spain      T  All levels of education   T  Total
# 190     ITA           Italy      T  All levels of education   T  Total
# 286     PRT        Portugal      T  All levels of education   T  Total
# 366     USA   United States      T  All levels of education   T  Total
# 14      AUS       Australia      T  All levels of education   T  Total
# 446     LTU       Lithuania      T  All levels of education   T  Total
# 158     ISL         Iceland      T  All levels of education   T  Total
# 238     NZL     New Zealand      T  All levels of education   T  Total
# 414     ISR          Israel      T  All levels of education   T  Total
# 430     LVA          Latvia      T  All levels of education   T  Total
# 142     GRC          Greece      T  All levels of education   T  Total
# 62      CZE  Czech Republic      T  All levels of education   T  Total
# 270     POL          Poland      T  All levels of education   T  Total
# 334     TUR         Türkiye      T  All levels of education   T  Total
#
#         AGE          Age PIAAC_CATEGORY Category             INDICATOR  \
# 222  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 30   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 318  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 206  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 78   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 254  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 94   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 110  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 46   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 398  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 174  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 382  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 126  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 350  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 302  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 190  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 286  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 366  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 14   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 446  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 158  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 238  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 414  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 430  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 142  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 62   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 270  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
# 334  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_FAMILY
#
#                                              Indicator MEASURE Measure  YEAR  \
# 222  Percentage of adults who reported that over th...   VALUE   Value  2016
# 30   Percentage of adults who reported that over th...   VALUE   Value  2016
# 318  Percentage of adults who reported that over th...   VALUE   Value  2016
# 206  Percentage of adults who reported that over th...   VALUE   Value  2016
# 78   Percentage of adults who reported that over th...   VALUE   Value  2016
# 254  Percentage of adults who reported that over th...   VALUE   Value  2015
# 94   Percentage of adults who reported that over th...   VALUE   Value  2016
# 110  Percentage of adults who reported that over th...   VALUE   Value  2015
# 46   Percentage of adults who reported that over th...   VALUE   Value  2016
# 398  Percentage of adults who reported that over th...   VALUE   Value  2016
# 174  Percentage of adults who reported that over th...   VALUE   Value  2016
# 382  Percentage of adults who reported that over th...   VALUE   Value  2015
# 126  Percentage of adults who reported that over th...   VALUE   Value  2015
# 350  Percentage of adults who reported that over th...   VALUE   Value  2016
# 302  Percentage of adults who reported that over th...   VALUE   Value  2015
# 190  Percentage of adults who reported that over th...   VALUE   Value  2016
# 286  Percentage of adults who reported that over th...   VALUE   Value  2016
# 366  Percentage of adults who reported that over th...   VALUE   Value  2015
# 14   Percentage of adults who reported that over th...   VALUE   Value  2015
# 446  Percentage of adults who reported that over th...   VALUE   Value  2016
# 158  Percentage of adults who reported that over th...   VALUE   Value  2015
# 238  Percentage of adults who reported that over th...   VALUE   Value  2015
# 414  Percentage of adults who reported that over th...   VALUE   Value  2015
# 430  Percentage of adults who reported that over th...   VALUE   Value  2016
# 142  Percentage of adults who reported that over th...   VALUE   Value  2016
# 62   Percentage of adults who reported that over th...   VALUE   Value  2016
# 270  Percentage of adults who reported that over th...   VALUE   Value  2016
# 334  Percentage of adults who reported that over th...   VALUE   Value  2016
#
#      Reference year  Value Flag Codes Flags
# 222            2016   18.0        NaN   NaN
# 30             2016   22.0        NaN   NaN
# 318            2016   22.0        NaN   NaN
# 206            2016   22.0        NaN   NaN
# 78             2016   24.0        NaN   NaN
# 254            2015   24.0        NaN   NaN
# 94             2016   25.0        NaN   NaN
# 110            2015   25.0        NaN   NaN
# 46             2016   26.0        NaN   NaN
# 398            2016   26.0        NaN   NaN
# 174            2016   26.0        NaN   NaN
# 382            2015   27.0        NaN   NaN
# 126            2015   27.0        NaN   NaN
# 350            2016   29.0        NaN   NaN
# 302            2015   29.0        NaN   NaN
# 190            2016   33.0        NaN   NaN
# 286            2016   34.0        NaN   NaN
# 366            2015   35.0        NaN   NaN
# 14             2015   35.0        NaN   NaN
# 446            2016   35.0        NaN   NaN
# 158            2015   36.0        NaN   NaN
# 238            2015   38.0        NaN   NaN
# 414            2015   39.0        NaN   NaN
# 430            2016   42.0        NaN   NaN
# 142            2016   44.0        NaN   NaN
# 62             2016   44.0        NaN   NaN
# 270            2016   47.0        NaN   NaN
# 334            2016   75.0        NaN   NaN

# %%
work_conc = work_conc.sort_values("Value")
work_conc
# Out:
#     COUNTRY         Country ISC11A             ISCED-A 2011 SEX Gender  \
# 166     IRL         Ireland      T  All levels of education   T  Total
# 214     NLD     Netherlands      T  All levels of education   T  Total
# 70      DNK         Denmark      T  All levels of education   T  Total
# 86      FIN         Finland      T  All levels of education   T  Total
# 310     SWE          Sweden      T  All levels of education   T  Total
# 198     LUX      Luxembourg      T  All levels of education   T  Total
# 374     CHL           Chile      T  All levels of education   T  Total
# 22      AUT         Austria      T  All levels of education   T  Total
# 406     ISR          Israel      T  All levels of education   T  Total
# 278     PRT        Portugal      T  All levels of education   T  Total
# 246     NOR          Norway      T  All levels of education   T  Total
# 150     ISL         Iceland      T  All levels of education   T  Total
# 342     GBR  United Kingdom      T  All levels of education   T  Total
# 390     EST         Estonia      T  All levels of education   T  Total
# 38      BEL         Belgium      T  All levels of education   T  Total
# 294     ESP           Spain      T  All levels of education   T  Total
# 358     USA   United States      T  All levels of education   T  Total
# 118     DEU         Germany      T  All levels of education   T  Total
# 438     LTU       Lithuania      T  All levels of education   T  Total
# 182     ITA           Italy      T  All levels of education   T  Total
# 230     NZL     New Zealand      T  All levels of education   T  Total
# 102     FRA          France      T  All levels of education   T  Total
# 422     LVA          Latvia      T  All levels of education   T  Total
# 6       AUS       Australia      T  All levels of education   T  Total
# 134     GRC          Greece      T  All levels of education   T  Total
# 262     POL          Poland      T  All levels of education   T  Total
# 54      CZE  Czech Republic      T  All levels of education   T  Total
# 326     TUR         Türkiye      T  All levels of education   T  Total
#
#         AGE          Age PIAAC_CATEGORY Category          INDICATOR  \
# 166  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 214  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 70   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 86   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 310  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 198  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 374  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 22   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 406  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 278  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 246  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 150  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 342  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 390  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 38   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 294  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 358  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 118  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 438  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 182  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 230  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 102  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 422  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 6    Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 134  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 262  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 54   Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
# 326  Y25T64  25-64 years              T    Total  EQLS_PERC_NEG_JOB
#
#                                              Indicator MEASURE Measure  YEAR  \
# 166  Percentage of adults who reported that over th...   VALUE   Value  2016
# 214  Percentage of adults who reported that over th...   VALUE   Value  2016
# 70   Percentage of adults who reported that over th...   VALUE   Value  2016
# 86   Percentage of adults who reported that over th...   VALUE   Value  2016
# 310  Percentage of adults who reported that over th...   VALUE   Value  2016
# 198  Percentage of adults who reported that over th...   VALUE   Value  2016
# 374  Percentage of adults who reported that over th...   VALUE   Value  2015
# 22   Percentage of adults who reported that over th...   VALUE   Value  2016
# 406  Percentage of adults who reported that over th...   VALUE   Value  2015
# 278  Percentage of adults who reported that over th...   VALUE   Value  2016
# 246  Percentage of adults who reported that over th...   VALUE   Value  2015
# 150  Percentage of adults who reported that over th...   VALUE   Value  2015
# 342  Percentage of adults who reported that over th...   VALUE   Value  2016
# 390  Percentage of adults who reported that over th...   VALUE   Value  2016
# 38   Percentage of adults who reported that over th...   VALUE   Value  2016
# 294  Percentage of adults who reported that over th...   VALUE   Value  2015
# 358  Percentage of adults who reported that over th...   VALUE   Value  2015
# 118  Percentage of adults who reported that over th...   VALUE   Value  2015
# 438  Percentage of adults who reported that over th...   VALUE   Value  2016
# 182  Percentage of adults who reported that over th...   VALUE   Value  2016
# 230  Percentage of adults who reported that over th...   VALUE   Value  2015
# 102  Percentage of adults who reported that over th...   VALUE   Value  2015
# 422  Percentage of adults who reported that over th...   VALUE   Value  2016
# 6    Percentage of adults who reported that over th...   VALUE   Value  2015
# 134  Percentage of adults who reported that over th...   VALUE   Value  2016
# 262  Percentage of adults who reported that over th...   VALUE   Value  2016
# 54   Percentage of adults who reported that over th...   VALUE   Value  2016
# 326  Percentage of adults who reported that over th...   VALUE   Value  2016
#
#      Reference year  Value Flag Codes Flags
# 166            2016   35.0        NaN   NaN
# 214            2016   39.0        NaN   NaN
# 70             2016   39.0        NaN   NaN
# 86             2016   39.0        NaN   NaN
# 310            2016   42.0        NaN   NaN
# 198            2016   43.0        NaN   NaN
# 374            2015   43.0        NaN   NaN
# 22             2016   43.0        NaN   NaN
# 406            2015   44.0        NaN   NaN
# 278            2016   46.0        NaN   NaN
# 246            2015   47.0        NaN   NaN
# 150            2015   48.0        NaN   NaN
# 342            2016   49.0        NaN   NaN
# 390            2016   49.0        NaN   NaN
# 38             2016   50.0        NaN   NaN
# 294            2015   52.0        NaN   NaN
# 358            2015   52.0        NaN   NaN
# 118            2015   54.0        NaN   NaN
# 438            2016   55.0        NaN   NaN
# 182            2016   55.0        NaN   NaN
# 230            2015   60.0        NaN   NaN
# 102            2015   60.0        NaN   NaN
# 422            2016   62.0        NaN   NaN
# 6              2015   63.0        NaN   NaN
# 134            2016   64.0        NaN   NaN
# 262            2016   67.0        NaN   NaN
# 54             2016   68.0        NaN   NaN
# 326            2016   81.0        NaN   NaN

# %%
import pandas as pd

# Assuming work_conc and family_resp are the existing DataFrames

# Merge the DataFrames on "Country" column
merged_df = pd.merge(work_conc, family_resp, on="Country")
merged_df = pd.merge(merged_df, new_df, on="Country")
# Create a new DataFrame with desired columns
work_life2 = pd.DataFrame()
work_life2["Country"] = merged_df["Country"]
work_life2["work_conc"] = merged_df["Value_x"]
work_life2["family_resp"] = merged_df["Value_y"]
work_life2["Average"] = (merged_df["Value_x"] + merged_df["Value_y"]) / 2
work_life2["Happiness"] = merged_df["2015"]

# Print the new DataFrame
work_life2.sort_values("Average", ascending=False)
# Out:
#            Country  work_conc  family_resp  Average  Happiness
# 24          Poland       67.0         47.0     57.0      5.975
# 23          Greece       64.0         44.0     54.0      5.824
# 21          Latvia       62.0         42.0     52.0      6.130
# 22       Australia       63.0         35.0     49.0      7.226
# 19     New Zealand       60.0         38.0     49.0      7.284
# 17       Lithuania       55.0         35.0     45.0      6.455
# 18           Italy       55.0         33.0     44.0      6.505
# 15   United States       52.0         35.0     43.5      6.983
# 20          France       60.0         25.0     42.5      6.901
# 10         Iceland       48.0         36.0     42.0      7.527
# 7           Israel       44.0         39.0     41.5      7.286
# 16         Germany       54.0         27.0     40.5      7.187
# 14           Spain       52.0         29.0     40.5      6.575
# 8         Portugal       46.0         34.0     40.0      5.833
# 11  United Kingdom       49.0         29.0     39.0      6.946
# 13         Belgium       50.0         26.0     38.0      6.937
# 12         Estonia       49.0         26.0     37.5      6.329
# 9           Norway       47.0         24.0     35.5      7.364
# 5            Chile       43.0         27.0     35.0      6.003
# 6          Austria       43.0         22.0     32.5      7.278
# 4           Sweden       42.0         22.0     32.0      7.378
# 3          Finland       39.0         25.0     32.0      7.587
# 2          Denmark       39.0         24.0     31.5      7.561
# 0          Ireland       35.0         26.0     30.5      7.200
# 1      Netherlands       39.0         18.0     28.5      7.427

# %%
import numpy as np
from scipy.stats import pearsonr

# Assuming work_life2 is the DataFrame containing "Average", "Happiness", and "Country" columns

# Create a scatter plot
plt.scatter(work_life2['Happiness'], work_life2['Average'])

# Add labels for each point
for i, country in enumerate(work_life2['Country']):
    plt.text(work_life2['Happiness'][i], work_life2['Average'][i], country)

# Calculate the line of best fit
slope, intercept = np.polyfit(work_life2['Happiness'], work_life2['Average'], 1)
line_of_best_fit = slope * work_life2['Happiness'] + intercept

# Plot the line of best fit
plt.plot(work_life2['Happiness'], line_of_best_fit, color='red')

# Set axis labels
plt.xlabel('Happiness')
plt.ylabel('Average')

# Set the plot title
plt.title('Average vs Happiness by Country')

# Calculate the correlation coefficient
correlation, _ = pearsonr(work_life2['Happiness'], work_life2['Average'])
print("Correlation coefficient:", correlation)

# Display the plot
plt.show()
# Out:
# Correlation coefficient: -0.5478216475197462

# %% [markdown]
# The pearson(r) correlation coefficient is -0.548
# The P-Value is .005. The result is significant at p < .05.
#
# This graph shows the Average between percent of people who feel like work is interfering with their personal life, and the percent of people who think their personal life is interfering with their work. That average is plotted against each country's happiness value for the year 2015, which is the year the work-life study was completed. The result is a moderate, yet significant negative correlation between the two variables.
